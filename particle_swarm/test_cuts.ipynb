# %%
import os,sys,inspect
os.chdir('/home/sharwinbobde/Studies/Q4/Evol Algos/Project/Evolutionary-Algorithms-Project')

from utils.graph_manager import GraphManager
import networkx as nx
import matplotlib as plt
from pyswarms.utils.plotters import (plot_cost_history, plot_contour, plot_surface)

# %%
def print_cuts(gm, A, B):
    print('-- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- ')
    print('cut      = ' + str(gm.cut_cost(A, B)))
    print('norm_cut = ' + str(gm.cut_normalised_cost(A, B)))
    print('cond     = ' + str(gm.cut_conductance(A, B)))
    print('e_exp    = ' + str(gm.cut_edge_expansion(A, B)))
    print('m_exp    = ' + str(gm.cut_mixing_expansion(A, B)))
    print('-- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- ')

# %% [markdown]
# # Set A

# %%
gm = GraphManager('data/maxcut/set0a/n0000006i01.txt', verbose=True)

# good
A = [4,5,3]
B = [2,6,1]
print_cuts(gm, A, B)

# shit
A = [5,4,2,]
B = [3,6,1]
print_cuts(gm, A, B)


gm.draw_graph('kk')
# Out:
# |N| = 6
# |E| = 15
# bkv = 31
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# cut      = 31
# norm_cut = 1.415672029060716
# cond     = 0.7560975609756098
# e_exp    = 10.333333333333334
# m_exp    = 1.0333333333333334
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# cut      = 27
# norm_cut = 1.2279069767441861
# cond     = 0.627906976744186
# e_exp    = 9.0
# m_exp    = 0.9
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --

# %% [markdown]
# # Set B (2D Mesh)

# %%
gm = GraphManager('data/maxcut/set0b/n0000009i00.txt', verbose=True)

# good
A = [1,9,7,3,5]
B = [4,8,6,2]
print_cuts(gm, A, B)

# shit
A = [5,4,2,]
B = [3,6,1]
print_cuts(gm, A, B)


gm.draw_graph('kk')
# Out:
# |N| = 9
# |E| = 12
# bkv = 36
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# cut      = 36
# norm_cut = 2.0
# cond     = 1.0
# e_exp    = 9.0
# m_exp    = 1.5
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# cut      = 13
# norm_cut = 1.0242424242424244
# cond     = 0.5909090909090909
# e_exp    = 4.333333333333333
# m_exp    = 0.5416666666666666
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --

# %% [markdown]
# # Set C

# %%
gm = GraphManager('data/maxcut/set0c/n0000009i00.txt', verbose=True)

# good
A = [8,3,4,2,9]
B = [1,5,7,9,6]
print_cuts(gm, A, B)

# # shit
# A = [5,4,2,]
# B = [3,6,1]
# print_cuts(gm, A, B)


gm.draw_graph('kk')
# Out:
# |N| = 9
# |E| = 18
# bkv = 45
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# cut      = 42
# norm_cut = 1.4963768115942029
# cond     = 0.9130434782608695
# e_exp    = 10.5
# m_exp    = 1.1666666666666667
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --

# %% [markdown]
# # Set D

# %%
gm = GraphManager('data/maxcut/set0d/n0000006i00.txt', verbose=False)
G = gm.G
gm.draw_graph('kk')

# %% [markdown]
# # Set E

# %%
gm = GraphManager('data/maxcut/set0e/n0000012i04.txt', verbose=False)
G = gm.G
gm.draw_graph('kk')
